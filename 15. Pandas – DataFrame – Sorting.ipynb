# %%
import pandas as pd
df = pd.read_csv("sales4.csv")

# %%
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
df2 = df.sort_values(by="Product_Cost")

# %%
df2
# Out:
#         Order_Id Customer_Name  Customer_Id              Product_Name  \
# 52994      54017       Sumanth           22    Samsung Galaxy S9 Plus
# 122987    124010       Karteek            4          27in FHD Monitor
# 16661      17684          Venu           23              Google Phone
# 122986    124009        Harsha            5                  iPhone 9
# 122974    123997       Lavanya           16    34in Ultrawide Monitor
# ...          ...           ...          ...                       ...
# 273569    274592  Jaya Chandra           21        Macbook Pro Laptop
# 273565    274588        Partha            8  Apple Airpods Headphones
# 171470    172493         Veeru            3          27in FHD Monitor
# 76102      77125       Lavanya           16        Samsung Galaxy S20
# 76472      77495    Nireekshan            1        Samsung Galaxy S20
#
#         Product_Cost
# 52994          50000
# 122987         50000
# 16661          50000
# 122986         50000
# ...

# %%
df2 = df.sort_values(by = "Customer_Id")

# %%
df2
# Out:
#         Order_Id Customer_Name  Customer_Id            Product_Name  \
# 160540    161563    Nireekshan            1        27in FHD Monitor
# 158658    159681    Nireekshan            1      Macbook Pro Laptop
# 266895    267918    Nireekshan            1      LG Washing Machine
# 266908    267931    Nireekshan            1            Google Phone
# 183395    184418    Nireekshan            1  LG ThinQ Refrigerator
# ...          ...           ...          ...                     ...
# 104589    105612         Shafi           25  LG ThinQ Refrigerator
# 194864    195887         Shafi           25               iPhone 11
# 223127    224150         Shafi           25      Samsung Galaxy S20
# 249626    250649         Shafi           25      Macbook Pro Laptop
# 109653    110676         Shafi           25  Samsung Galaxy S9 Plus
#
#         Product_Cost
# 160540         75000
# 158658         63999
# 266895         59000
# 266908         55000
# 183395         69000
# ...

# %%
df2 = df.sort_values(by = "Customer_Id",ascending = False)

# %%
df2
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 225837    226860         Shafi           25        Apple iPad 10.2-inch
# 58299      59322         Shafi           25             ThinkPad Laptop
# 122755    123778         Shafi           25          Samsung Galaxy S20
# 220596    221619         Shafi           25  Bose SoundSport Headphones
# 9252       10275         Shafi           25               Flatscreen TV
# ...          ...           ...          ...                         ...
# 191789    192812    Nireekshan            1               Flatscreen TV
# 146543    147566    Nireekshan            1                   iPhone 7s
# 283770    284793    Nireekshan            1    Apple Airpods Headphones
# 79317      80340    Nireekshan            1                20in Monitor
# 78470      79493    Nireekshan            1                   iPhone 7s
#
#         Product_Cost
# 225837         69999
# 58299          63999
# 122755         61000
# ...

# %%
df2 = df.sort_values(by = "Customer_Id",ascending = 0)

# %%
df2
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 225837    226860         Shafi           25        Apple iPad 10.2-inch
# 58299      59322         Shafi           25             ThinkPad Laptop
# 122755    123778         Shafi           25          Samsung Galaxy S20
# 220596    221619         Shafi           25  Bose SoundSport Headphones
# 9252       10275         Shafi           25               Flatscreen TV
# ...          ...           ...          ...                         ...
# 191789    192812    Nireekshan            1               Flatscreen TV
# 146543    147566    Nireekshan            1                   iPhone 7s
# 283770    284793    Nireekshan            1    Apple Airpods Headphones
# 79317      80340    Nireekshan            1                20in Monitor
# 78470      79493    Nireekshan            1                   iPhone 7s
#
#         Product_Cost
# 225837         69999
# 58299          63999
# 122755         61000
# ...

# %%
df2 = df.sort_values(by = "Customer_Name")

# %%
df2
# Out:
#         Order_Id Customer_Name  Customer_Id            Product_Name  \
# 136196    137219        Balaji           12               LG Mobile
# 128754    129777        Balaji           12      Samsung Galaxy S20
# 292113    293136        Balaji           12               LG Mobile
# 128753    129776        Balaji           12  LG ThinQ Refrigerator
# 73777      74800        Balaji           12    Apple iPad 10.2-inch
# ...          ...           ...          ...                     ...
# 280203    281226         Vinay           10                iPhone 8
# 155180    156203         Vinay           10  Samsung Galaxy S9 Plus
# 82486      83509         Vinay           10  LG ThinQ Refrigerator
# 26986      28009         Vinay           10               iPhone 11
# 186628    187651         Vinay           10  LG ThinQ Refrigerator
#
#         Product_Cost
# 136196         60000
# 128754         61000
# 292113         65999
# 128753         65999
# 73777          51999
# ...

# %%
# Sorting dataframe by using sort_index()

# %%
d = {
    'Order id':[11,12,31],
    'Customer name':['Kedar','Nireekshan','Daniel'],
    'Product':['iPhone 11','hTC','macbook']
}


i = [555,444,333]

# %%
df = pd.DataFrame(d,index = i)

# %%
df2 = df.sort_index()

# %%
df
# Out:
#      Order id Customer name    Product
# 555        11         Kedar  iPhone 11
# 444        12    Nireekshan        hTC
# 333        31        Daniel    macbook

# %%
df2
# Out:
#      Order id Customer name    Product
# 333        31        Daniel    macbook
# 444        12    Nireekshan        hTC
# 555        11         Kedar  iPhone 11
