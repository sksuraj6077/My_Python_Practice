# %%
# Date data type

import pandas as pd

df = pd.read_csv('sales7_dates.csv')

print(df.head())
print()
print(df.dtypes)
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost       Pur_Date
# 0         59000  1/1/2019 0:00
# 1         69000  1/1/2019 1:00
# 2         65999  1/1/2019 2:00
# 3         63999  1/1/2019 3:00
# 4         63999  1/1/2019 4:00
#
# Order_Id          int64
# Customer_Name    object
# Customer_Id       int64
# Product_Name     object
# Product_Cost      int64
# Pur_Date         object
# dtype: object

# %%
df['Pur_Date']=pd.to_datetime(df['Pur_Date'])
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date
# 0         59000 2019-01-01 00:00:00
# 1         69000 2019-01-01 01:00:00
# 2         65999 2019-01-01 02:00:00
# 3         63999 2019-01-01 03:00:00
# 4         63999 2019-01-01 04:00:00

# %%
df.dtypes
# Out:
# Order_Id                  int64
# Customer_Name            object
# Customer_Id               int64
# Product_Name             object
# Product_Cost              int64
# Pur_Date         datetime64[ns]
# dtype: object

# %%
df = pd.read_csv('sales7_dates.csv')
df['Pur_Date']=df['Pur_Date'].astype('datetime64[ns]')

# %%
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date
# 0         59000 2019-01-01 00:00:00
# 1         69000 2019-01-01 01:00:00
# 2         65999 2019-01-01 02:00:00
# 3         63999 2019-01-01 03:00:00
# 4         63999 2019-01-01 04:00:00

# %%
# Format parameter

# %%
data = {
    'Product': ['Samsung', 'iPhone', 'Motorola'],
    'Status': ['Success', 'Success', 'Failed'],
    'Cost': [10000, 50000, 15000],
    'PurDate': ['20190902','20190913','20190921'],
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     Product   Status   Cost   PurDate
# 0   Samsung  Success  10000  20190902
# 1    iPhone  Success  50000  20190913
# 2  Motorola   Failed  15000  20190921

# %%
# Converting Date with specific format

df['PurDate']=pd.to_datetime(df['PurDate'])
df.head()
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21

# %%
# Converting Date with specific format
data = {
    "Product": ["Samsung", "iPhone", "Motorola"],
    "Status": ["Success", "Success", "Failed"],
    "Cost": [10000, 50000, 15000],
    "PurDate": ['02092019','13092019','21092019'],
}

data = pd.DataFrame(data)
data['PurDate']=pd.to_datetime(data['PurDate'],format = '%d%m%Y')
print(data)
data.head()
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21

# %%
df.dtypes
# Out:
# Product            object
# Status             object
# Cost                int64
# PurDate    datetime64[ns]
# dtype: object

# %%
data = {
    "Product": ["Samsung", "iPhone", "Motorola"],
    "Status": ["Success", "Success", "Failed"],
    "Cost": [10000, 50000, 15000],
    "PurDate": ['02Sep2019','13Sep2019','21Sep2019'],
}

data = pd.DataFrame(data)
print(data)
data['PurDate'] = pd.to_datetime(data["PurDate"])
data.head()
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000  02Sep2019
# 1    iPhone  Success  50000  13Sep2019
# 2  Motorola   Failed  15000  21Sep2019
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21

# %%
data
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21

# %%
# Converting Date with specific format

data= {
    "Product": ["Samsung", "iPhone", "Motorola"],
    "Status": ["Success", "Success", "Failed"],
    "Cost": [10000, 50000, 15000],
    "PurDate": ['02Sep2019','13Sep2019','21Sep2019'],
}

# %%
data = pd.DataFrame(data)
print(data)
data['PurDate'] = pd.to_datetime(data['PurDate'])
data
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000  02Sep2019
# 1    iPhone  Success  50000  13Sep2019
# 2  Motorola   Failed  15000  21Sep2019
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000 2019-09-13
# 2  Motorola   Failed  15000 2019-09-21

# %%
data = {
    "Product": ["Samsung", "iPhone", "Motorola"],
    "Status": ["Success", "Success", "Failed"],
    "Cost": [10000, 50000, 15000],
    "PurDate": ['20190902093000','20190913093000','20190921200000'],
}

# %%
data = pd.DataFrame(data)
print(data)
# Out:
#     Product   Status   Cost         PurDate
# 0   Samsung  Success  10000  20190902093000
# 1    iPhone  Success  50000  20190913093000
# 2  Motorola   Failed  15000  20190921200000

# %%
data['PurDate'] = pd.to_datetime(data['PurDate'])
data
# Out:
#     Product   Status   Cost             PurDate
# 0   Samsung  Success  10000 2019-09-02 09:30:00
# 1    iPhone  Success  50000 2019-09-13 09:30:00
# 2  Motorola   Failed  15000 2019-09-21 20:00:00

# %%
data1 = {
"Product": ["Samsung", "iPhone", "Motorola"],
"Status": ["Success", "Success", "Failed"],
"Cost": [10000, 50000, 15000],
"PurDate": ['02-Sep-2019','Here date is missing','21-Sep-2019']
}

# %%
data1 = pd.DataFrame(data1)
data1
# Out:
#     Product   Status   Cost               PurDate
# 0   Samsung  Success  10000           02-Sep-2019
# 1    iPhone  Success  50000  Here date is missing
# 2  Motorola   Failed  15000           21-Sep-2019

# %%
data1['PurDate'] = pd.to_datetime(data1['PurDate'])
data1
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File E:\anaconda\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File E:\anaconda\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: Here date is missing
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "Here date is missing" at position 1
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data1['PurDate'] = pd.to_datetime(data1['PurDate'])
#       2 data1
#
# File E:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File E:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File E:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File E:\anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File E:\anaconda\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File E:\anaconda\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: Here date is missing present at position 1

# %%
data1['PurDate'] = pd.to_datetime(data1['PurDate'],errors = "coerce")
data1
# Out:
#     Product   Status   Cost    PurDate
# 0   Samsung  Success  10000 2019-09-02
# 1    iPhone  Success  50000        NaT
# 2  Motorola   Failed  15000 2019-09-21

# %%
# Selecting Dataframe in between the dates

# %%
df1 = pd.read_csv('sales7_dates.csv')
print(df1)
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost         Pur_Date
# 0            59000    1/1/2019 0:00
# 1            69000    1/1/2019 1:00
# 2            65999    1/1/2019 2:00
# 3            63999    1/1/2019 3:00
# 4            63999    1/1/2019 4:00
# ...            ...              ...
# 9994         51999  2/21/2020 10:00
# 9995         75999  2/21/2020 11:00
# 9996         75999  2/21/2020 12:00
# 9997         65999  2/21/2020 13:00
# 9998         55000  2/21/2020 14:00
#
# [9999 rows x 6 columns]

# %%
df = pd.read_csv('sales7_dates.csv',parse_dates=['Pur_Date'])
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date
# 0         59000 2019-01-01 00:00:00
# 1         69000 2019-01-01 01:00:00
# 2         65999 2019-01-01 02:00:00
# 3         63999 2019-01-01 03:00:00
# 4         63999 2019-01-01 04:00:00

# %%
start = df['Pur_Date']> '2019-1-1 01:00:00'
end = df['Pur_Date']< '2019-2-2 05:00:00'

result = df[start & end]
(result)
# Out:
#      Order_Id Customer_Name  Customer_Id                Product_Name  \
# 2        1025        Shahid           20  Bose SoundSport Headphones
# 3        1026         Veeru            3        Apple iPad 10.2-inch
# 4        1027          Venu           23                Google Phone
# 5        1028        Daniel            6      Samsung Galaxy S9 Plus
# 6        1029          Venu           23                   iPhone 11
# ..        ...           ...          ...                         ...
# 768      1791        Harsha            5                20in Monitor
# 769      1792         Shafi           25                   iPhone 7s
# 770      1793        Daniel            6             ThinkPad Laptop
# 771      1794        Daniel            6                   iPhone 11
# 772      1795    Nireekshan            1          Macbook Pro Laptop
#
#      Product_Cost            Pur_Date
# 2           65999 2019-01-01 02:00:00
# 3           63999 2019-01-01 03:00:00
# 4           63999 2019-01-01 04:00:00
# 5           63999 2019-01-01 05:00:00
# 6           61000 2019-01-01 06:00:00
# ..            ...                 ...
# 768         60000 2019-02-02 00:00:00
# 769         69000 2019-02-02 01:00:00
# 770         61000 2019-02-02 02:00:00
# 771         63000 2019-02-02 03:00:00
# 772         59000 2019-02-02 04:00:00
#
# [771 rows x 6 columns]

# %%
# Accessing last 10 days records


new = df.set_index('Pur_Date')
days_10 = new.last('10D')

# %%
days_10
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-02-11 15:00:00     10782        Harsha            5
# 2020-02-11 16:00:00     10783         Veeru            3
# 2020-02-11 17:00:00     10784         Vinay           10
# 2020-02-11 18:00:00     10785  Jaya Chandra           21
# 2020-02-11 19:00:00     10786        Shahid           20
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
#                                  Product_Name  Product_Cost
# Pur_Date
# 2020-02-11 15:00:00              Google Phone         75000
# 2020-02-11 16:00:00              Google Phone         61000
# 2020-02-11 17:00:00    34in Ultrawide Monitor         69999
# 2020-02-11 18:00:00           ThinkPad Laptop         50000
# 2020-02-11 19:00:00                 iPhone 11         51999
# ...                                       ...           ...
# 2020-02-21 10:00:00              20in Monitor         51999
# 2020-02-21 11:00:00  Apple Airpods Headphones         75999
# 2020-02-21 12:00:00    LG ThinQ Refrigerator          75999
# 2020-02-21 13:00:00                 iPhone 7s         65999
# 2020-02-21 14:00:00    34in Ultrawide Monitor         55000
#
# [240 rows x 5 columns]

# %%
# Accessing last 40 days records
new.head()
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2019-01-01 00:00:00      1023         Venki           15
# 2019-01-01 01:00:00      1024    Chaithanya           14
# 2019-01-01 02:00:00      1025        Shahid           20
# 2019-01-01 03:00:00      1026         Veeru            3
# 2019-01-01 04:00:00      1027          Venu           23
#
#                                    Product_Name  Product_Cost
# Pur_Date
# 2019-01-01 00:00:00            27in FHD Monitor         59000
# 2019-01-01 01:00:00                   iPhone 11         69000
# 2019-01-01 02:00:00  Bose SoundSport Headphones         65999
# 2019-01-01 03:00:00        Apple iPad 10.2-inch         63999
# 2019-01-01 04:00:00                Google Phone         63999

# %%
days_40 = new.last('40D')
print(days_40)
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-01-12 15:00:00     10062     Madhurima            7
# 2020-01-12 16:00:00     10063       Pradhan           17
# 2020-01-12 17:00:00     10064          Venu           23
# 2020-01-12 18:00:00     10065         Venki           15
# 2020-01-12 19:00:00     10066        Balaji           12
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
#                                  Product_Name  Product_Cost
# Pur_Date
# 2020-01-12 15:00:00              Google Phone         51999
# 2020-01-12 16:00:00           ThinkPad Laptop         63000
# 2020-01-12 17:00:00    LG ThinQ Refrigerator          69000
# 2020-01-12 18:00:00           ThinkPad Laptop         60000
# 2020-01-12 19:00:00             Flatscreen TV         65000
# ...                                       ...           ...
# 2020-02-21 10:00:00              20in Monitor         51999
# 2020-02-21 11:00:00  Apple Airpods Headphones         75999
# 2020-02-21 12:00:00    LG ThinQ Refrigerator          75999
# 2020-02-21 13:00:00                 iPhone 7s         65999
# 2020-02-21 14:00:00    34in Ultrawide Monitor         55000
#
# [960 rows x 5 columns]

# %%
# Accessing last 1 month records

month_1 = new.last('1M')
month_1
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-01-31 15:00:00     10518       Pradhan           17
# 2020-01-31 16:00:00     10519         Shafi           25
# 2020-01-31 17:00:00     10520         Veeru            3
# 2020-01-31 18:00:00     10521        Balaji           12
# 2020-01-31 19:00:00     10522       Pradhan           17
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
#                                  Product_Name  Product_Cost
# Pur_Date
# 2020-01-31 15:00:00    LG ThinQ Refrigerator          65999
# 2020-01-31 16:00:00        Samsung Galaxy S20         63000
# 2020-01-31 17:00:00    34in Ultrawide Monitor         59000
# 2020-01-31 18:00:00        Macbook Pro Laptop         50000
# 2020-01-31 19:00:00                 iPhone 7s         51999
# ...                                       ...           ...
# 2020-02-21 10:00:00              20in Monitor         51999
# 2020-02-21 11:00:00  Apple Airpods Headphones         75999
# 2020-02-21 12:00:00    LG ThinQ Refrigerator          75999
# 2020-02-21 13:00:00                 iPhone 7s         65999
# 2020-02-21 14:00:00    34in Ultrawide Monitor         55000
#
# [504 rows x 5 columns]

# %%
new.head()
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2019-01-01 00:00:00      1023         Venki           15
# 2019-01-01 01:00:00      1024    Chaithanya           14
# 2019-01-01 02:00:00      1025        Shahid           20
# 2019-01-01 03:00:00      1026         Veeru            3
# 2019-01-01 04:00:00      1027          Venu           23
#
#                                    Product_Name  Product_Cost
# Pur_Date
# 2019-01-01 00:00:00            27in FHD Monitor         59000
# 2019-01-01 01:00:00                   iPhone 11         69000
# 2019-01-01 02:00:00  Bose SoundSport Headphones         65999
# 2019-01-01 03:00:00        Apple iPad 10.2-inch         63999
# 2019-01-01 04:00:00                Google Phone         63999

# %%
# Accessing last 1 year records

year_1 = new.last("1Y")
year_1
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2019-12-31 15:00:00      9774         Veeru            3
# 2019-12-31 16:00:00      9775         Shafi           25
# 2019-12-31 17:00:00      9776        Shahid           20
# 2019-12-31 18:00:00      9777         Venki           15
# 2019-12-31 19:00:00      9778       Sumanth           22
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
#                                  Product_Name  Product_Cost
# Pur_Date
# 2019-12-31 15:00:00          27in FHD Monitor         65999
# 2019-12-31 16:00:00    27in 4K Gaming Monitor         65999
# 2019-12-31 17:00:00        Samsung Galaxy S20         50000
# 2019-12-31 18:00:00    27in 4K Gaming Monitor         50000
# 2019-12-31 19:00:00              Google Phone         65999
# ...                                       ...           ...
# 2020-02-21 10:00:00              20in Monitor         51999
# 2020-02-21 11:00:00  Apple Airpods Headphones         75999
# 2020-02-21 12:00:00    LG ThinQ Refrigerator          75999
# 2020-02-21 13:00:00                 iPhone 7s         65999
# 2020-02-21 14:00:00    34in Ultrawide Monitor         55000
#
# [1248 rows x 5 columns]

# %% [markdown]
# ### Extract year, month, day from Date column
# > Based on requirement we can get year, month, day, hour, minute from Date column.
# > Sometimes it can be useful to break up a column of dates into components.

# %%
df = pd.read_csv('sales7_dates.csv',parse_dates=['Pur_Date'])

# %%
df['Year']=df['Pur_Date'].dt.year

# %%
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year
# 0         59000 2019-01-01 00:00:00  2019
# 1         69000 2019-01-01 01:00:00  2019
# 2         65999 2019-01-01 02:00:00  2019
# 3         63999 2019-01-01 03:00:00  2019
# 4         63999 2019-01-01 04:00:00  2019

# %%
df['Month']=df['Pur_Date'].dt.month

# %%
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year  Month
# 0         59000 2019-01-01 00:00:00  2019      1
# 1         69000 2019-01-01 01:00:00  2019      1
# 2         65999 2019-01-01 02:00:00  2019      1
# 3         63999 2019-01-01 03:00:00  2019      1
# 4         63999 2019-01-01 04:00:00  2019      1

# %%
df['Day'] = df['Pur_Date'].dt.day
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year  Month  Day
# 0         59000 2019-01-01 00:00:00  2019      1    1
# 1         69000 2019-01-01 01:00:00  2019      1    1
# 2         65999 2019-01-01 02:00:00  2019      1    1
# 3         63999 2019-01-01 03:00:00  2019      1    1
# 4         63999 2019-01-01 04:00:00  2019      1    1

# %%
# Breaking up the Date column value into multiple features

df['Hour']=df['Pur_Date'].dt.hour
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year  Month  Day  Hour
# 0         59000 2019-01-01 00:00:00  2019      1    1     0
# 1         69000 2019-01-01 01:00:00  2019      1    1     1
# 2         65999 2019-01-01 02:00:00  2019      1    1     2
# 3         63999 2019-01-01 03:00:00  2019      1    1     3
# 4         63999 2019-01-01 04:00:00  2019      1    1     4

# %%
df['Minute'] = df['Pur_Date'].dt.minute
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year  Month  Day  Hour  Minute
# 0         59000 2019-01-01 00:00:00  2019      1    1     0       0
# 1         69000 2019-01-01 01:00:00  2019      1    1     1       0
# 2         65999 2019-01-01 02:00:00  2019      1    1     2       0
# 3         63999 2019-01-01 03:00:00  2019      1    1     3       0
# 4         63999 2019-01-01 04:00:00  2019      1    1     4       0

# %%
df['Second'] = df['Pur_Date'].dt.second
df.head()
# Out:
#    Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0      1023         Venki           15            27in FHD Monitor
# 1      1024    Chaithanya           14                   iPhone 11
# 2      1025        Shahid           20  Bose SoundSport Headphones
# 3      1026         Veeru            3        Apple iPad 10.2-inch
# 4      1027          Venu           23                Google Phone
#
#    Product_Cost            Pur_Date  Year  Month  Day  Hour  Minute  Second
# 0         59000 2019-01-01 00:00:00  2019      1    1     0       0       0
# 1         69000 2019-01-01 01:00:00  2019      1    1     1       0       0
# 2         65999 2019-01-01 02:00:00  2019      1    1     2       0       0
# 3         63999 2019-01-01 03:00:00  2019      1    1     3       0       0
# 4         63999 2019-01-01 04:00:00  2019      1    1     4       0       0

# %%
df['Day_Name'] = df['Pur_Date'].dt.day_name()
df.head(100)
# Out:
#     Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0       1023         Venki           15            27in FHD Monitor
# 1       1024    Chaithanya           14                   iPhone 11
# 2       1025        Shahid           20  Bose SoundSport Headphones
# 3       1026         Veeru            3        Apple iPad 10.2-inch
# 4       1027          Venu           23                Google Phone
# ..       ...           ...          ...                         ...
# 95      1118    Nireekshan            1      LG ThinQ Refrigerator
# 96      1119         Vinay           10          Samsung Galaxy S20
# 97      1120  Jaya Chandra           21                    iPhone 8
# 98      1121         Kedar            2                   iPhone 11
# 99      1122     Madhurima            7                   iPhone 11
#
#     Product_Cost            Pur_Date  Year  Month  Day  Hour  Minute  Second  \
# 0          59000 2019-01-01 00:00:00  2019      1    1     0       0       0
# 1          69000 2019-01-01 01:00:00  2019      1    1     1       0       0
# 2          65999 2019-01-01 02:00:00  2019      1    1     2       0       0
# 3          63999 2019-01-01 03:00:00  2019      1    1     3       0       0
# 4          63999 2019-01-01 04:00:00  2019      1    1     4       0       0
# ..           ...                 ...   ...    ...  ...   ...     ...     ...
# 95         69000 2019-01-04 23:00:00  2019      1    4    23       0       0
# 96         69000 2019-01-05 00:00:00  2019      1    5     0       0       0
# 97         69999 2019-01-05 01:00:00  2019      1    5     1       0       0
# 98         75999 2019-01-05 02:00:00  2019      1    5     2       0       0
# 99         63000 2019-01-05 03:00:00  2019      1    5     3       0       0
#
#     Day_Name
# 0    Tuesday
# 1    Tuesday
# 2    Tuesday
# 3    Tuesday
# 4    Tuesday
# ..       ...
# 95    Friday
# 96  Saturday
# 97  Saturday
# 98  Saturday
# 99  Saturday
#
# [100 rows x 13 columns]

# %%
df['Week_Day']=df['Pur_Date'].dt.weekday
df.head(100)
# Out:
#     Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0       1023         Venki           15            27in FHD Monitor
# 1       1024    Chaithanya           14                   iPhone 11
# 2       1025        Shahid           20  Bose SoundSport Headphones
# 3       1026         Veeru            3        Apple iPad 10.2-inch
# 4       1027          Venu           23                Google Phone
# ..       ...           ...          ...                         ...
# 95      1118    Nireekshan            1      LG ThinQ Refrigerator
# 96      1119         Vinay           10          Samsung Galaxy S20
# 97      1120  Jaya Chandra           21                    iPhone 8
# 98      1121         Kedar            2                   iPhone 11
# 99      1122     Madhurima            7                   iPhone 11
#
#     Product_Cost            Pur_Date  Year  Month  Day  Hour  Minute  Second  \
# 0          59000 2019-01-01 00:00:00  2019      1    1     0       0       0
# 1          69000 2019-01-01 01:00:00  2019      1    1     1       0       0
# 2          65999 2019-01-01 02:00:00  2019      1    1     2       0       0
# 3          63999 2019-01-01 03:00:00  2019      1    1     3       0       0
# 4          63999 2019-01-01 04:00:00  2019      1    1     4       0       0
# ..           ...                 ...   ...    ...  ...   ...     ...     ...
# 95         69000 2019-01-04 23:00:00  2019      1    4    23       0       0
# 96         69000 2019-01-05 00:00:00  2019      1    5     0       0       0
# 97         69999 2019-01-05 01:00:00  2019      1    5     1       0       0
# 98         75999 2019-01-05 02:00:00  2019      1    5     2       0       0
# 99         63000 2019-01-05 03:00:00  2019      1    5     3       0       0
#
#     Day_Name  Week_Day
# 0    Tuesday         1
# 1    Tuesday         1
# 2    Tuesday         1
# 3    Tuesday         1
# 4    Tuesday         1
# ..       ...       ...
# 95    Friday         4
# 96  Saturday         5
# 97  Saturday         5
# 98  Saturday         5
# 99  Saturday         5
#
# [100 rows x 14 columns]

# %%
data = {
'Product': ['Samsung', 'iPhone', 'Motorola'],
'Status': ['Success', 'Success', 'Failed'],
'Cost': [10000, 50000, 15000],
'PurDate': ['2018-01-01','2018-01-02','2018-01-03'],
}

# %%
data = pd.DataFrame(data)

# %%
data['PurDate'] = pd.to_datetime(data['PurDate'])
data.dtypes
# Out:
# Product            object
# Status             object
# Cost                int64
# PurDate    datetime64[ns]
# dtype: object

# %%
data["Day_Name"]=data['PurDate'].dt.day_name()

# %%
data
# Out:
#     Product   Status   Cost    PurDate   Day_Name
# 0   Samsung  Success  10000 2018-01-01     Monday
# 1    iPhone  Success  50000 2018-01-02    Tuesday
# 2  Motorola   Failed  15000 2018-01-03  Wednesday

# %%
data['Week_Day']=data['PurDate'].dt.weekday

# %%
data
# Out:
#     Product   Status   Cost    PurDate   Day_Name  Week_Day
# 0   Samsung  Success  10000 2018-01-01     Monday         0
# 1    iPhone  Success  50000 2018-01-02    Tuesday         1
# 2  Motorola   Failed  15000 2018-01-03  Wednesday         2
