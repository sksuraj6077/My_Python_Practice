# %%
# Selecting single column from the DataFrame

import pandas as pd

df = pd.read_csv("sales1.csv")
df
# Out:
#      Order ID Customer Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %%
print(df.Product)
# Out:
# 0      34in Ultrawide Monitor
# 1                 Samsung m10
# 2                20in Monitor
# 3                   iPhone 11
# 4          Macbook Pro Laptop
#                 ...
# 595        Macbook Pro Laptop
# 596           ThinkPad Laptop
# 597             Flatscreen TV
# 598               Samsung m20
# 599        LG Washing Machine
# Name: Product, Length: 600, dtype: object

# %%
s = df["Product"]

# %%
s
# Out:
# 0      34in Ultrawide Monitor
# 1                 Samsung m10
# 2                20in Monitor
# 3                   iPhone 11
# 4          Macbook Pro Laptop
#                 ...
# 595        Macbook Pro Laptop
# 596           ThinkPad Laptop
# 597             Flatscreen TV
# 598               Samsung m20
# 599        LG Washing Machine
# Name: Product, Length: 600, dtype: object

# %%
df.Product
# Out:
# 0      34in Ultrawide Monitor
# 1                 Samsung m10
# 2                20in Monitor
# 3                   iPhone 11
# 4          Macbook Pro Laptop
#                 ...
# 595        Macbook Pro Laptop
# 596           ThinkPad Laptop
# 597             Flatscreen TV
# 598               Samsung m20
# 599        LG Washing Machine
# Name: Product, Length: 600, dtype: object

# %%
l1 = df.columns

# %%
l1
# Out:
# Index(['Order ID', 'Customer Name', 'Product', 'Quantity'], dtype='object')

# %%
df.Quantity
# Out:
# 0      2
# 1      3
# 2      1
# 3      3
# 4      2
#       ..
# 595    1
# 596    1
# 597    1
# 598    2
# 599    1
# Name: Quantity, Length: 600, dtype: int64

# %%
# Selecting multiple columns from the DataFrame

df[["Customer Name","Order ID"]]
# Out:
#     Customer Name  Order ID
# 0           Veeru    166837
# 1           Tarun    166838
# 2           Kedar    166839
# 3         Lavanya    166840
# 4            Venu    166841
# ..            ...       ...
# 595        Balaji    167403
# 596       Lavanya    167404
# 597          Venu    167405
# 598        Siddhu    167406
# 599         Tarun    167407
#
# [600 rows x 2 columns]

# %%
# Selecting single column from the DataFrame, apply total

total = df['Quantity'].sum()

# %%
total
# Out:
# 889

# %%
# Select specific customer from existing DataFrame

# %%
df
# Out:
#      Order ID Customer Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %% [markdown]
# ## Select specific customer from existing DataFrame

# %%
cust_name_Tarun = df['Customer Name'] == 'Tarun'

# %%
df[cust_name_Tarun]
# Out:
#      Order ID Customer Name                     Product  Quantity
# 1      166838         Tarun                 Samsung m10         3
# 18     166854         Tarun                    iPhone 7         1
# 21     166857         Tarun            27in FHD Monitor         1
# 101    166936         Tarun  Bose SoundSport Headphones         1
# 107    166942         Tarun                20in Monitor         1
# 118    166953         Tarun                20in Monitor         1
# 136    166970         Tarun          Macbook Pro Laptop         2
# 174    167003         Tarun  Bose SoundSport Headphones         2
# 248    167072         Tarun                   iPhone 11         1
# 276    167099         Tarun    Apple Airpods Headphones         1
# 288    167110         Tarun            Wired Headphones         1
# 330    167150         Tarun             ThinkPad Laptop         1
# 331    167151         Tarun                   iPhone 7s         1
# ...

# %%
cust_name_Balaji =df["Customer Name"] == "Balaji"

# %%
df[cust_name_Balaji]
# Out:
#      Order ID Customer Name                     Product  Quantity
# 93     166928        Balaji                    iPhone 9         1
# 162    166992        Balaji                   iPhone 7s         2
# 189    167018        Balaji             ThinkPad Laptop         1
# 197    167025        Balaji                 Samsung m20         3
# 199    167027        Balaji          Macbook Pro Laptop         1
# 258    167081        Balaji        USB-C Charging Cable         1
# 271    167094        Balaji               Flatscreen TV         2
# 278    167101        Balaji                   iPhone 11         2
# 308    167128        Balaji      27in 4K Gaming Monitor         1
# 353    167172        Balaji          Macbook Pro Laptop         1
# 371    167190        Balaji                 Samsung m10         1
# 372    167191        Balaji      27in 4K Gaming Monitor         1
# 417    167235        Balaji             ThinkPad Laptop         3
# ...

# %% [markdown]
# ## Select specific quantity from existing DataFrame

# %%
# which orders Quantity == 1

quantity_1 =df["Quantity"] == 1

# %%
df[quantity_1]
# Out:
#      Order ID Customer Name             Product  Quantity
# 2      166839         Kedar        20in Monitor         1
# 7      166844        Harsha         Samsung m10         1
# 9      166846        Siddhu           iPhone 11         1
# 11     166848       Karteek  Macbook Pro Laptop         1
# 12     166849        Shahid     ThinkPad Laptop         1
# ..        ...           ...                 ...       ...
# 594    167402         Kedar         Samsung m10         1
# 595    167403        Balaji  Macbook Pro Laptop         1
# 596    167404       Lavanya     ThinkPad Laptop         1
# 597    167405          Venu       Flatscreen TV         1
# 599    167407         Tarun  LG Washing Machine         1
#
# [376 rows x 4 columns]

# %% [markdown]
# ## Select specific Product from existing DataFrame

# %%
# where Product == "Samsung m10"

# %%
product_Samsung_m10 = df["Product"] == "Samsung m10"

# %%
df[product_Samsung_m10]
# Out:
#      Order ID Customer Name      Product  Quantity
# 1      166838         Tarun  Samsung m10         3
# 7      166844        Harsha  Samsung m10         1
# 10     166847          Venu  Samsung m10         2
# 17     166853         Kedar  Samsung m10         1
# 19     166855       Sumanth  Samsung m10         2
# 54     166890        Harsha  Samsung m10         1
# 65     166901         Veeru  Samsung m10         2
# 74     166910    Nireekshan  Samsung m10         2
# 92     166927        Harsha  Samsung m10         1
# 98     166933        Shahid  Samsung m10         2
# 113    166948         Veeru  Samsung m10         1
# 114    166949         Sagar  Samsung m10         1
# 129    166964         Veeru  Samsung m10         1
# 138    166972     Madhurima  Samsung m10         1
# 147    166980        Harsha  Samsung m10         1
# 150    166981       Lavanya  Samsung m10         3
# 151    166981   Mallikarjun  Samsung m10         2
# ...

# %%
# iloc and loc indexers

# %%
df1 = pd.read_csv("sales2.csv")

# %%
df1
# Out:
#      Order id Customer name  Customer id                Product name  \
# 0      192837        Partha            8        Apple iPad 10.2-inch
# 1      192838         Vinay           10               Flatscreen TV
# 2      192839       Lavanya           16                20in Monitor
# 3      192840         Mohan           24  Bose SoundSport Headphones
# 4      192841         Kedar            2                Google Phone
# ..        ...           ...          ...                         ...
# 895    193732        Balaji           12          Samsung Galaxy S20
# 896    193733       Neelima           19      27in 4K Gaming Monitor
# 897    193734        Siddhu           18                Google Phone
# 898    193735         Vinay           10                20in Monitor
# 899    193736     Madhurima            7            27in FHD Monitor
#
#      Product cost
# 0           59000
# 1           65999
# 2           75000
# 3           55000
# 4           59000
# ..            ...
# ...

# %%
# We can select single or multiple rows by using iloc indexer

# %%
df1.iloc[0]
# Out:
# Order id                       192837
# Customer name                  Partha
# Customer id                         8
# Product name     Apple iPad 10.2-inch
# Product cost                    59000
# Name: 0, dtype: object

# %%
df1.iloc[1]
# Out:
# Order id                192838
# Customer name            Vinay
# Customer id                 10
# Product name     Flatscreen TV
# Product cost             65999
# Name: 1, dtype: object

# %%
df1.iloc[-1]
# Out:
# Order id                   193736
# Customer name           Madhurima
# Customer id                     7
# Product name     27in FHD Monitor
# Product cost                55999
# Name: 899, dtype: object

# %%
df1.iloc[-3]
# Out:
# Order id               193734
# Customer name          Siddhu
# Customer id                18
# Product name     Google Phone
# Product cost            69999
# Name: 897, dtype: object

# %%
df1.iloc[:,0]
# Out:
# 0      192837
# 1      192838
# 2      192839
# 3      192840
# 4      192841
#         ...
# 895    193732
# 896    193733
# 897    193734
# 898    193735
# 899    193736
# Name: Order id, Length: 900, dtype: int64

# %%
df1.iloc[:,1]
# Out:
# 0         Partha
# 1          Vinay
# 2        Lavanya
# 3          Mohan
# 4          Kedar
#          ...
# 895       Balaji
# 896      Neelima
# 897       Siddhu
# 898        Vinay
# 899    Madhurima
# Name: Customer name, Length: 900, dtype: object

# %%
df1.iloc[:,-1]
# Out:
# 0      59000
# 1      65999
# 2      75000
# 3      55000
# 4      59000
#        ...
# 895    60000
# 896    75999
# 897    69999
# 898    69999
# 899    55999
# Name: Product cost, Length: 900, dtype: int64

# %%
# First five rows from dataframe

# %%
df1.iloc[0:5]
# Out:
#    Order id Customer name  Customer id                Product name  \
# 0    192837        Partha            8        Apple iPad 10.2-inch
# 1    192838         Vinay           10               Flatscreen TV
# 2    192839       Lavanya           16                20in Monitor
# 3    192840         Mohan           24  Bose SoundSport Headphones
# 4    192841         Kedar            2                Google Phone
#
#    Product cost
# 0         59000
# 1         65999
# 2         75000
# 3         55000
# 4         59000

# %%
df1.iloc[3:10]
# Out:
#    Order id Customer name  Customer id                Product name  \
# 3    192840         Mohan           24  Bose SoundSport Headphones
# 4    192841         Kedar            2                Google Phone
# 5    192842       Karteek            4          LG Washing Machine
# 6    192843        Harsha            5                   iPhone 11
# 7    192844       Pradhan           17          Macbook Pro Laptop
# 8    192845        Balaji           12          Macbook Pro Laptop
# 9    192846       Pradhan           17      27in 4K Gaming Monitor
#
#    Product cost
# 3         55000
# 4         59000
# 5         75000
# 6         55999
# 7         75999
# 8         75000
# 9         65000

# %%
# First two columns of the dataframe with all rows

df1.iloc[:,0:2]
# Out:
#      Order id Customer name
# 0      192837        Partha
# 1      192838         Vinay
# 2      192839       Lavanya
# 3      192840         Mohan
# 4      192841         Kedar
# ..        ...           ...
# 895    193732        Balaji
# 896    193733       Neelima
# 897    193734        Siddhu
# 898    193735         Vinay
# 899    193736     Madhurima
#
# [900 rows x 2 columns]

# %%
# First three columns of the dataframe with all rows

df1.iloc[:,0:3]
# Out:
#      Order id Customer name  Customer id
# 0      192837        Partha            8
# 1      192838         Vinay           10
# 2      192839       Lavanya           16
# 3      192840         Mohan           24
# 4      192841         Kedar            2
# ..        ...           ...          ...
# 895    193732        Balaji           12
# 896    193733       Neelima           19
# 897    193734        Siddhu           18
# 898    193735         Vinay           10
# 899    193736     Madhurima            7
#
# [900 rows x 3 columns]

# %%
df1.shape
# Out:
# (900, 5)

# %%
# find first 5 rows and first 2 columns of the DataFrame?
df1.iloc[0:5,0:2]
# Out:
#    Order id Customer name
# 0    192837        Partha
# 1    192838         Vinay
# 2    192839       Lavanya
# 3    192840         Mohan
# 4    192841         Kedar

# %%
# find first 5 rows and first 3 columns of the DataFrame?

df1.iloc[0:5,0:3]
# Out:
#    Order id Customer name  Customer id
# 0    192837        Partha            8
# 1    192838         Vinay           10
# 2    192839       Lavanya           16
# 3    192840         Mohan           24
# 4    192841         Kedar            2

# %%
# loc Indexer

# %%
"""
This indexer used to get rows or columns with particular labels from the index.
The loc indexer is label based data selection means we have to pass the name of the row or column which we want to select.
The loc indexer can also do boolean selection
This includes the last element in DataFrame
"""
# Out:
# '\nThis indexer used to get rows or columns with particular labels from the index.\nThe loc indexer is label based data selection means we have to pass the name of the row or column which we want to select.\nThe loc indexer can also do boolean selection\nThis includes the last element in DataFrame\n'

# %%
df1
# Out:
#      Order id Customer name  Customer id                Product name  \
# 0      192837        Partha            8        Apple iPad 10.2-inch
# 1      192838         Vinay           10               Flatscreen TV
# 2      192839       Lavanya           16                20in Monitor
# 3      192840         Mohan           24  Bose SoundSport Headphones
# 4      192841         Kedar            2                Google Phone
# ..        ...           ...          ...                         ...
# 895    193732        Balaji           12          Samsung Galaxy S20
# 896    193733       Neelima           19      27in 4K Gaming Monitor
# 897    193734        Siddhu           18                Google Phone
# 898    193735         Vinay           10                20in Monitor
# 899    193736     Madhurima            7            27in FHD Monitor
#
#      Product cost
# 0           59000
# 1           65999
# 2           75000
# 3           55000
# 4           59000
# ..            ...
# ...

# %%
df1.set_index("Product name",inplace = True)

# %%
df1
# Out:
#                             Order id Customer name  Customer id  Product cost
# Product name
# Apple iPad 10.2-inch          192837        Partha            8         59000
# Flatscreen TV                 192838         Vinay           10         65999
# 20in Monitor                  192839       Lavanya           16         75000
# Bose SoundSport Headphones    192840         Mohan           24         55000
# Google Phone                  192841         Kedar            2         59000
# ...                              ...           ...          ...           ...
# Samsung Galaxy S20            193732        Balaji           12         60000
# 27in 4K Gaming Monitor        193733       Neelima           19         75999
# Google Phone                  193734        Siddhu           18         69999
# 20in Monitor                  193735         Vinay           10         69999
# 27in FHD Monitor              193736     Madhurima            7         55999
#
# ...

# %%
df2 = df1.loc["iPhone 9"]

# %%
df2
# Out:
#               Order id Customer name  Customer id  Product cost
# Product name
# iPhone 9        192861         Sagar            6         60000
# iPhone 9        192867         Shafi            3         65000
# iPhone 9        192891         Sagar            6         50000
# iPhone 9        192902        Balaji           12         69999
# iPhone 9        192914  Jaya Chandra           21         59000
# iPhone 9        192921         Venki           15         50000
# iPhone 9        192939         Tarun           11         55999
# iPhone 9        192969        Siddhu           18         65000
# iPhone 9        192984       Neelima           19         69000
# iPhone 9        192998         Vinay           10         75999
# iPhone 9        193015     Madhurima            7         75000
# iPhone 9        193051         Sagar            6         55999
# iPhone 9        193052       Sumanth           22         65999
# ...

# %%
# Setting index as a Product name and selecting Product
df2 = df1.loc["ThinkPad Laptop"]

# %%
df2
# Out:
#                  Order id Customer name  Customer id  Product cost
# Product name
# ThinkPad Laptop    192859         Vijay            9         75000
# ThinkPad Laptop    192862        Harsha            5         55000
# ThinkPad Laptop    192868        Balaji           12         75999
# ThinkPad Laptop    192888  Jaya Chandra           21         75000
# ThinkPad Laptop    192915        Balaji           12         50000
# ThinkPad Laptop    192974        Siddhu           18         69000
# ThinkPad Laptop    192983         Sagar            6         63999
# ThinkPad Laptop    192989         Venki           15         65000
# ThinkPad Laptop    192999   Mallikarjun           13         69999
# ThinkPad Laptop    193014       Sumanth           22         55999
# ThinkPad Laptop    193026         Venki           15         50000
# ThinkPad Laptop    193069    Chaithanya           14         50000
# ThinkPad Laptop    193079        Harsha            5         65000
# ...

# %%
df2 = df1.loc[['iPhone 9',"ThinkPad Laptop"]]

# %%
df2
# Out:
#                  Order id Customer name  Customer id  Product cost
# Product name
# iPhone 9           192861         Sagar            6         60000
# iPhone 9           192867         Shafi            3         65000
# iPhone 9           192891         Sagar            6         50000
# iPhone 9           192902        Balaji           12         69999
# iPhone 9           192914  Jaya Chandra           21         59000
# ...                   ...           ...          ...           ...
# ThinkPad Laptop    193586       Pradhan           17         63000
# ThinkPad Laptop    193649        Siddhu           18         50000
# ThinkPad Laptop    193664   Mallikarjun           13         63000
# ThinkPad Laptop    193715         Venki           15         65999
# ThinkPad Laptop    193726       Pradhan           17         59000
#
# [82 rows x 4 columns]

# %%
a = ['iPhone 9', 'ThinkPad Laptop']
b = ['Product cost', 'Customer id']

# %%
df2 = df1.loc[a,b]

# %%
df2
# Out:
#                  Product cost  Customer id
# Product name
# iPhone 9                60000            6
# iPhone 9                65000            3
# iPhone 9                50000            6
# iPhone 9                69999           12
# iPhone 9                59000           21
# ...                       ...          ...
# ThinkPad Laptop         63000           17
# ThinkPad Laptop         50000           18
# ThinkPad Laptop         63000           13
# ThinkPad Laptop         65999           15
# ThinkPad Laptop         59000           17
#
# [82 rows x 2 columns]

# %%
df11 = pd.read_csv("sales1.csv")

# %%
df11.set_index("Product",inplace = True)

# %%
df11
# Out:
#                         Order ID Customer Name  Quantity
# Product
# 34in Ultrawide Monitor    166837         Veeru         2
# Samsung m10               166838         Tarun         3
# 20in Monitor              166839         Kedar         1
# iPhone 11                 166840       Lavanya         3
# Macbook Pro Laptop        166841          Venu         2
# ...                          ...           ...       ...
# Macbook Pro Laptop        167403        Balaji         1
# ThinkPad Laptop           167404       Lavanya         1
# Flatscreen TV             167405          Venu         1
# Samsung m20               167406        Siddhu         2
# LG Washing Machine        167407         Tarun         1
#
# [600 rows x 3 columns]

# %%
df2 = df1.loc["20in Monitor"]

# %%
df2
# Out:
#               Order id Customer name  Customer id  Product cost
# Product name
# 20in Monitor    192839       Lavanya           16         75000
# 20in Monitor    192879   Mallikarjun           13         55000
# 20in Monitor    192889  Jaya Chandra           21         59000
# 20in Monitor    192892       Karteek            4         75000
# 20in Monitor    192903         Venki           15         55000
# 20in Monitor    192910    Nireekshan            1         69999
# 20in Monitor    192917        Shahid           20         75999
# 20in Monitor    192987        Balaji           12         63999
# 20in Monitor    193025       Karteek            4         65999
# 20in Monitor    193058         Venki           15         51999
# 20in Monitor    193064        Harsha            5         65999
# 20in Monitor    193124         Sagar            6         61000
# 20in Monitor    193141    Chaithanya           14         55000
# ...

# %%
df3 = df1.loc[["20in Monitor"],["Product cost","Customer name"]]

# %%
df3
# Out:
#               Product cost Customer name
# Product name
# 20in Monitor         75000       Lavanya
# 20in Monitor         55000   Mallikarjun
# 20in Monitor         59000  Jaya Chandra
# 20in Monitor         75000       Karteek
# 20in Monitor         55000         Venki
# 20in Monitor         69999    Nireekshan
# 20in Monitor         75999        Shahid
# 20in Monitor         63999        Balaji
# 20in Monitor         65999       Karteek
# 20in Monitor         51999         Venki
# 20in Monitor         65999        Harsha
# 20in Monitor         61000         Sagar
# 20in Monitor         55000    Chaithanya
# 20in Monitor         65999        Balaji
# 20in Monitor         69000         Shafi
# 20in Monitor         65999        Siddhu
# 20in Monitor         75000        Harsha
# 20in Monitor         51999         Tarun
# 20in Monitor         63000       Lavanya
# 20in Monitor         69000     Madhurima
# 20in Monitor         69999  Jaya Chandra
# ...

# %%
df11 = pd.read_csv("sales2.csv")

# %%
df11
# Out:
#                             Order id Customer name  Customer id  Product cost
# Product name
# Apple iPad 10.2-inch          192837        Partha            8         59000
# Flatscreen TV                 192838         Vinay           10         65999
# 20in Monitor                  192839       Lavanya           16         75000
# Bose SoundSport Headphones    192840         Mohan           24         55000
# Google Phone                  192841         Kedar            2         59000
# ...                              ...           ...          ...           ...
# Samsung Galaxy S20            193732        Balaji           12         60000
# 27in 4K Gaming Monitor        193733       Neelima           19         75999
# Google Phone                  193734        Siddhu           18         69999
# 20in Monitor                  193735         Vinay           10         69999
# 27in FHD Monitor              193736     Madhurima            7         55999
#
# ...

# %%
df11.set_index("Product name",inplace = True)

# %%
a = ['iPhone 8', 'Google Phone']
df2 = df1.loc[a, 'Order id' : 'Customer id']

# %%
df2
# Out:
#               Order id Customer name  Customer id
# Product name
# iPhone 8        192865        Siddhu           18
# iPhone 8        192874       Sumanth           22
# iPhone 8        192878  Jaya Chandra           21
# iPhone 8        192881       Lavanya           16
# iPhone 8        192897    Chaithanya           14
# ...                ...           ...          ...
# Google Phone    193666       Karteek            4
# Google Phone    193672       Karteek            4
# Google Phone    193725   Mallikarjun           13
# Google Phone    193729    Chaithanya           14
# Google Phone    193734        Siddhu           18
#
# [93 rows x 3 columns]

# %%
df2 = df1.loc[a,"Customer name":"Product cost"]

# %%
df2
# Out:
#              Customer name  Customer id  Product cost
# Product name
# iPhone 8            Siddhu           18         59000
# iPhone 8           Sumanth           22         69999
# iPhone 8      Jaya Chandra           21         69000
# iPhone 8           Lavanya           16         65000
# iPhone 8        Chaithanya           14         69999
# ...                    ...          ...           ...
# Google Phone       Karteek            4         50000
# Google Phone       Karteek            4         75000
# Google Phone   Mallikarjun           13         75999
# Google Phone    Chaithanya           14         65000
# Google Phone        Siddhu           18         69999
#
# [93 rows x 3 columns]

# %%
df2 = df1.loc[a,"Order id"]

# %%
df2
# Out:
# Product name
# iPhone 8        192865
# iPhone 8        192874
# iPhone 8        192878
# iPhone 8        192881
# iPhone 8        192897
#                  ...
# Google Phone    193666
# Google Phone    193672
# Google Phone    193725
# Google Phone    193729
# Google Phone    193734
# Name: Order id, Length: 93, dtype: int64

# %%
#  Boolean / Logical indexing

# %%
df01 = pd.read_csv("sales2.csv")

# %%
a = df01['Product name'] == "LG Washing Machine"

# %%
df2 = df01.loc[a]

# %%
df2
# Out:
#      Order id Customer name  Customer id        Product name  Product cost
# 5      192842       Karteek            4  LG Washing Machine         75000
# 70     192907        Balaji           12  LG Washing Machine         65999
# 111    192948         Sagar            6  LG Washing Machine         63000
# 117    192954         Sagar            6  LG Washing Machine         61000
# 173    193010     Madhurima            7  LG Washing Machine         65000
# 175    193012       Neelima           19  LG Washing Machine         65999
# 196    193033        Shahid           20  LG Washing Machine         69000
# 207    193044        Balaji           12  LG Washing Machine         63000
# 243    193080        Shahid           20  LG Washing Machine         59000
# 274    193111       Neelima           19  LG Washing Machine         59000
# 337    193174        Harsha            5  LG Washing Machine         69999
# ...

# %%
df2 = df01.loc[a,'Order id':'Product cost']

# %%
df2
# Out:
#      Order id Customer name  Customer id        Product name  Product cost
# 5      192842       Karteek            4  LG Washing Machine         75000
# 70     192907        Balaji           12  LG Washing Machine         65999
# 111    192948         Sagar            6  LG Washing Machine         63000
# 117    192954         Sagar            6  LG Washing Machine         61000
# 173    193010     Madhurima            7  LG Washing Machine         65000
# 175    193012       Neelima           19  LG Washing Machine         65999
# 196    193033        Shahid           20  LG Washing Machine         69000
# 207    193044        Balaji           12  LG Washing Machine         63000
# 243    193080        Shahid           20  LG Washing Machine         59000
# 274    193111       Neelima           19  LG Washing Machine         59000
# 337    193174        Harsha            5  LG Washing Machine         69999
# ...

# %%
df2 = df01.loc[a,'Product name':'Product cost']

# %%
df2
# Out:
#            Product name  Product cost
# 5    LG Washing Machine         75000
# 70   LG Washing Machine         65999
# 111  LG Washing Machine         63000
# 117  LG Washing Machine         61000
# 173  LG Washing Machine         65000
# 175  LG Washing Machine         65999
# 196  LG Washing Machine         69000
# 207  LG Washing Machine         63000
# 243  LG Washing Machine         59000
# 274  LG Washing Machine         59000
# 337  LG Washing Machine         69999
# 344  LG Washing Machine         65000
# 346  LG Washing Machine         65999
# 357  LG Washing Machine         50000
# 374  LG Washing Machine         63000
# 426  LG Washing Machine         63999
# 429  LG Washing Machine         55000
# 486  LG Washing Machine         51999
# 510  LG Washing Machine         69000
# 520  LG Washing Machine         69999
# 523  LG Washing Machine         59000
# 530  LG Washing Machine         55000
# 532  LG Washing Machine         75999
# 539  LG Washing Machine         65999
# ...
